# %%
from IPython.display import Image
from IPython.core.display import display, HTML

# %%
Image(filename='images/pipenv_install.png')

# %%
Image(filename='images/pipenv_version.png')

# %%
Image(filename='images/scikit_learn_hash.png')

# %%
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/predict_pickle.py">predict_pickle.py</a>"""))

display(HTML("<h4>Churn probability of the customer:</h4>"))
# %run 'predict_pickle.py'
# Out:
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/predict_pickle.py">predict_pickle.py</a>
# <h4>Churn probability of the customer:</h4>
# 0.11549580587832914

# %%
display(HTML("<h4>All files used to create deployment server using gunicorn:</h4>"))
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/churn_flask_serving.py">churn_flask_serving.py</a>"""))
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/dv.bin">dv.bin</a>"""))
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/model1.bin">model1.bin</a>"""))
# Out:
# <h4>All files used to create deployment server using gunicorn:</h4>
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/churn_flask_serving.py">churn_flask_serving.py</a>
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/dv.bin">dv.bin</a>
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/model1.bin">model1.bin</a>

# %%
Image(filename='images/gunicorn.png')

# %%
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/test_flask_gunicorn.py">test_flask_gunicorn.py</a>"""))
display(HTML("<h4>Churn probability of the customer:</h4>"))
# %run 'test_flask_gunicorn.py'
# Out:
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/test_flask_gunicorn.py">test_flask_gunicorn.py</a>
# <h4>Churn probability of the customer:</h4>
# 0.9988892771007961

# %%
display(HTML("<h4>All files used to create docker image:</h4>"))
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/tree/main/Session5/churn_docker">churn_docker</a>"""))
# Out:
# <h4>All files used to create docker image:</h4>
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/tree/main/Session5/churn_docker">churn_docker</a>

# %%
Image(filename='images/docker.png')

# %%
display(HTML("""<a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/test_docker.py">test_docker.py</a>"""))

display(HTML("<h4>Churn probability of the customer:</h4>"))
# %run 'test_docker.py'
# Out:
# <a href="https://github.com/ramreddyyasa/ML-Zoomcamp/blob/main/Session5/test_docker.py">test_docker.py</a>
# <h4>Churn probability of the customer:</h4>
# 0.7284944888182928
